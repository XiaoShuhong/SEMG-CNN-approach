# %%
import os
import scipy.io as sio
import numpy as np
from itertools import product
from collections import namedtuple
from joblib import Parallel, delayed

# %%
subjects = list(range(0,27))  #27 person
gestures = list(range(1,53))  #52 different gestures
trials = list(range(10))      #10 channel

# %%
input_path = 'C:/Users/11488/Desktop/my semg/data'

# %% [markdown]
# #### Load My Data

# %%
#load my data
print('load S1_A1_E1.mat')
data1 = sio.loadmat('C:/Users/11488/Desktop/my semg/data/db-1/s1/S1_A1_E1.mat')
# print(data1.keys())
# print(data1['emg'].shape)
print(data1['stimulus'].shape)
# print(data1['stimulus'])
# data1['emg']
print('load S1_A1_E2.mat')
data2 = sio.loadmat('C:/Users/11488/Desktop/my semg/data/db-1/s1/S1_A1_E2.mat')

print('load S1_A1_E3.mat')
data3 = sio.loadmat('C:/Users/11488/Desktop/my semg/data/db-1/s1/S1_A1_E3.mat')
# Out:
# load S1_A1_E1.mat
# (101014, 1)
# load S1_A1_E2.mat
# load S1_A1_E3.mat

# %%
ch0=dict()
ch1=dict()
ch2=dict()
ch3=dict()
ch4=dict()
ch5=dict()
ch6=dict()
ch7=dict()
ch8=dict()
ch9=dict()
d0=[]
d1=[]
d2=[]
d3=[]
d4=[]
d5=[]
d6=[]
d7=[]
d8=[]
d9=[]
for i in range( data1['stimulus'].shape):
    if data['stimulus'][i]==[1]:
        d.append(data['emg'][i][0])
mov1['data']=d
sio.savemat('C:/Users/11488/Desktop/my semg/data/db-1/s1/test1.mat', mov1)

# %%
data = sio.loadmat('C:/Users/11488/Desktop/my semg/data/db-1/s1/test1.mat')
print(data.keys())
data['data'].shape
# Out:
# dict_keys(['__header__', '__version__', '__globals__', 'data'])
# (1, 5149)

# %%
filtering_type = 'lowpass'
framerate = 100

window_length_ms = 200
window_stride_ms = 10

window = window_length_ms*framerate/1000   #20
stride = window_stride_ms*framerate/1000   #1

# %%
output_path = ('C:/Users/11488/Desktop/my semg/wwt/ninapro-feature/ninapro-db1-var-raw-prepro-%s-win-%d-stride-%d' % (filtering_type, window, stride))

# %%
Combo = namedtuple('Combo', ['subject', 'gesture', 'trial']) #define a class Comb with attribute "subject" "gesture" "trial"

# %%
feature_list = ['ssc', 'var']  #slop sign change, variance

# %%
def get_combos(*args):
    for arg in args:
        if isinstance(arg, tuple):
            arg = [arg]
        for a in arg:
            yield Combo(*a)

# %%
def butter_lowpass_filter(data, cut, fs, order, zero_phase=False):
    from scipy.signal import butter, lfilter, filtfilt

    nyq = 0.5 * fs
    cut = cut / nyq

    b, a = butter(order, cut, btype='low')
    y = (filtfilt if zero_phase else lfilter)(b, a, data)
    return y

# %%
def get_segments(data, window, stride):
    return windowed_view(
        data.flat,
        window * data.shape[1],
        (window-stride)* data.shape[1]
    )

def windowed_view(arr, window, overlap):
    from numpy.lib.stride_tricks import as_strided
    arr = np.asarray(arr)
    window_step = window - overlap
    new_shape = arr.shape[:-1] + ((arr.shape[-1] - overlap) // window_step,
                                  window)
    new_strides = (arr.strides[:-1] + (window_step * arr.strides[-1],) +
                   arr.strides[-1:])
    return as_strided(arr, shape=new_shape, strides=new_strides)

# %%
# for i in combos:
#     in_path = os.path.join(
#                     input_path, 'data',
#                     '{c.subject:03d}',
#                     '{c.gesture:03d}',
#                     '{c.subject:03d}_{c.gesture:03d}_{c.trial:03d}.mat').format(c=i)
#     out_dir = os.path.join(
#                     output_path,
#                     '{c.subject:03d}',
#                     '{c.gesture:03d}').format(c=i)  
#     print(out_dir)

# %%
def emg_feature_extraction_parallel_2(input_path, output_path, combo, feature_list):
    in_path = os.path.join(
                input_path, 'data',
                '{c.subject:03d}',
                '{c.gesture:03d}',
                '{c.subject:03d}_{c.gesture:03d}_{c.trial:03d}.mat').format(c=combo)
                
    out_dir = os.path.join(
                    output_path,
                    '{c.subject:03d}',
                    '{c.gesture:03d}').format(c=combo)  
                
    if os.path.isdir(out_dir) is False:
             os.makedirs(out_dir)                 
     
                
    data = sio.loadmat(in_path)['data'].astype(np.float32)
        
    print ("Subject %d Gesture %d Trial %d data loaded!" % (combo.subject, combo.gesture, combo.trial))
      
        
      
    if filtering_type is 'lowpass':            
#             data = np.transpose([lowpass(ch, 1, framerate, 1, zero_phase=True) for ch in data.T])
        data = np.transpose([butter_lowpass_filter(ch, 1, framerate, 1, zero_phase=True) for ch in data.T])   
        print ("Subject %d Gesture %d Trial %d bandpass filtering finished!" % (combo.subject, combo.gesture, combo.trial))
    else:
        pass
           
#      data = downsample(data, step=20)        
        
    chnum = data.shape[1]    
    data = get_segments(data, window, stride)
      data = data.reshape(-1, window, chnum)
      
      for feature_name in feature_list:
          feature = [np.transpose(extract_emg_feature(seg.T, feature_name)) for seg in data]
          feature = np.array(feature)
          out_path = os.path.join(
                                  out_dir,
                                  '{0.subject:03d}_{0.gesture:03d}_{0.trial:03d}_{1}.mat').format(combo, feature_name)  
          sio.savemat(out_path, {'data': feature, 'label': combo.gesture, 'subject': combo.subject, 'trial':combo.trial})                        
          print ("Subject %d Gesture %d Trial %d %s saved!" % (combo.subject, combo.gesture, combo.trial, feature_name))

# %%
print ("NinaPro feature map generation, use window = %d frames, stride = %d frames" % (window, stride)) 

combos = get_combos(product(subjects, gestures, trials))
           
combos = list(combos)

combos
# Out:
# NinaPro feature map generation, use window = 20 frames, stride = 1 frames
# [Combo(subject=0, gesture=1, trial=0),
#  Combo(subject=0, gesture=1, trial=1),
#  Combo(subject=0, gesture=1, trial=2),
#  Combo(subject=0, gesture=1, trial=3),
#  Combo(subject=0, gesture=1, trial=4),
#  Combo(subject=0, gesture=1, trial=5),
#  Combo(subject=0, gesture=1, trial=6),
#  Combo(subject=0, gesture=1, trial=7),
#  Combo(subject=0, gesture=1, trial=8),
#  Combo(subject=0, gesture=1, trial=9),
#  Combo(subject=0, gesture=2, trial=0),
#  Combo(subject=0, gesture=2, trial=1),
#  Combo(subject=0, gesture=2, trial=2),
#  Combo(subject=0, gesture=2, trial=3),
#  Combo(subject=0, gesture=2, trial=4),
#  Combo(subject=0, gesture=2, trial=5),
#  Combo(subject=0, gesture=2, trial=6),
#  Combo(subject=0, gesture=29, trial=0),
#  Combo(subject=0, gesture=29, trial=1),
#  Combo(subject=0, gesture=29, trial=2),
#  Combo(subject=0, gesture=29, trial=3),
#  Combo(subject=0, gesture=29, trial=4),
#  Combo(subject=0, gesture=29, trial=5),
#  Combo(subject=0, gesture=29, trial=6),
#  Combo(subject=0, gesture=29, trial=7),
#  Combo(subject=0, gesture=29, trial=8),
#  Combo(subject=0, gesture=29, trial=9),
#  Combo(subject=0, gesture=30, trial=0),
#  Combo(subject=0, gesture=30, trial=1),
#  Combo(subject=0, gesture=30, trial=2),
#  Combo(subject=0, gesture=30, trial=3),
#  Combo(subject=0, gesture=30, trial=4),
#  Combo(subject=0, gesture=30, trial=5),
#  Combo(subject=0, gesture=30, trial=6),
#  Combo(subject=0, gesture=30, trial=7),
#  Combo(subject=0, gesture=30, trial=8),
#  Combo(subject=0, gesture=30, trial=9),
#  Combo(subject=0, gesture=31, trial=0),
#  Combo(subject=0, gesture=31, trial=1),
#  Combo(subject=0, gesture=31, trial=2),
#  Combo(subject=0, gesture=31, trial=3),
#  Combo(subject=0, gesture=31, trial=4),
#  Combo(subject=0, gesture=31, trial=5),
#  Combo(subject=0, gesture=31, trial=6),
#  Combo(subject=0, gesture=31, trial=7),
#  Combo(subject=0, gesture=31, trial=8),
#  Combo(subject=0, gesture=31, trial=9),
#  Combo(subject=0, gesture=32, trial=0),
#  Combo(subject=0, gesture=32, trial=1),
#  Combo(subject=0, gesture=32, trial=2),
#  Combo(subject=0, gesture=32, trial=3),
#  Combo(subject=0, gesture=32, trial=4),
#  Combo(subject=0, gesture=32, trial=5),
#  Combo(subject=0, gesture=32, trial=6),
#  Combo(subject=0, gesture=32, trial=7),
#  Combo(subject=0, gesture=32, trial=8),
#  Combo(subject=0, gesture=32, trial=9),
#  Combo(subject=0, gesture=33, trial=0),
#  Combo(subject=0, gesture=33, trial=1),
#  Combo(subject=0, gesture=33, trial=2),
#  Combo(subject=0, gesture=33, trial=3),
#  Combo(subject=0, gesture=33, trial=4),
#  Combo(subject=0, gesture=33, trial=5),
#  Combo(subject=0, gesture=33, trial=6),
#  Combo(subject=0, gesture=33, trial=7),
#  Combo(subject=0, gesture=33, trial=8),
#  Combo(subject=0, gesture=33, trial=9),
#  Combo(subject=0, gesture=34, trial=0),
#  Combo(subject=0, gesture=34, trial=1),
#  Combo(subject=0, gesture=34, trial=2),
#  Combo(subject=0, gesture=34, trial=3),
#  Combo(subject=0, gesture=34, trial=4),
#  Combo(subject=0, gesture=34, trial=5),
#  Combo(subject=0, gesture=34, trial=6),
#  Combo(subject=0, gesture=34, trial=7),
#  Combo(subject=0, gesture=34, trial=8),
#  Combo(subject=0, gesture=34, trial=9),
#  Combo(subject=0, gesture=35, trial=0),
#  Combo(subject=0, gesture=35, trial=1),
#  Combo(subject=0, gesture=35, trial=2),
#  Combo(subject=0, gesture=35, trial=3),
#  Combo(subject=0, gesture=35, trial=4),
#  Combo(subject=0, gesture=35, trial=5),
#  Combo(subject=0, gesture=48, trial=7),
#  Combo(subject=0, gesture=48, trial=8),
#  Combo(subject=0, gesture=48, trial=9),
#  Combo(subject=0, gesture=49, trial=0),
#  Combo(subject=0, gesture=49, trial=1),
#  Combo(subject=0, gesture=49, trial=2),
#  Combo(subject=0, gesture=49, trial=3),
#  Combo(subject=0, gesture=49, trial=4),
#  Combo(subject=0, gesture=49, trial=5),
#  Combo(subject=0, gesture=49, trial=6),
#  Combo(subject=0, gesture=49, trial=7),
#  Combo(subject=0, gesture=49, trial=8),
#  Combo(subject=0, gesture=49, trial=9),
#  Combo(subject=0, gesture=50, trial=0),
#  Combo(subject=0, gesture=50, trial=1),
#  Combo(subject=0, gesture=50, trial=2),
#  Combo(subject=0, gesture=50, trial=3),
#  Combo(subject=0, gesture=50, trial=4),
#  Combo(subject=0, gesture=50, trial=5),
#  Combo(subject=0, gesture=50, trial=6),
#  Combo(subject=0, gesture=50, trial=7),
#  Combo(subject=0, gesture=50, trial=8),
#  Combo(subject=0, gesture=50, trial=9),
#  Combo(subject=0, gesture=51, trial=0),
#  Combo(subject=0, gesture=51, trial=1),
#  Combo(subject=0, gesture=51, trial=2),
#  Combo(subject=0, gesture=51, trial=3),
#  Combo(subject=0, gesture=51, trial=4),
#  Combo(subject=0, gesture=51, trial=5),
#  Combo(subject=0, gesture=51, trial=6),
#  Combo(subject=0, gesture=51, trial=7),
#  Combo(subject=0, gesture=51, trial=8),
#  Combo(subject=0, gesture=51, trial=9),
#  Combo(subject=0, gesture=52, trial=0),
#  Combo(subject=0, gesture=52, trial=1),
#  Combo(subject=0, gesture=52, trial=2),
#  Combo(subject=0, gesture=52, trial=3),
#  Combo(subject=0, gesture=52, trial=4),
#  Combo(subject=0, gesture=52, trial=5),
#  Combo(subject=0, gesture=52, trial=6),
#  Combo(subject=0, gesture=52, trial=7),
#  Combo(subject=0, gesture=52, trial=8),
#  Combo(subject=0, gesture=52, trial=9),
#  Combo(subject=1, gesture=1, trial=0),
#  Combo(subject=1, gesture=1, trial=1),
#  Combo(subject=1, gesture=1, trial=2),
#  Combo(subject=1, gesture=1, trial=3),
#  Combo(subject=1, gesture=1, trial=4),
#  Combo(subject=1, gesture=1, trial=5),
#  Combo(subject=1, gesture=1, trial=6),
#  Combo(subject=1, gesture=1, trial=7),
#  Combo(subject=1, gesture=1, trial=8),
#  Combo(subject=1, gesture=1, trial=9),
#  Combo(subject=1, gesture=2, trial=0),
#  Combo(subject=1, gesture=2, trial=1),
#  Combo(subject=1, gesture=2, trial=2),
#  Combo(subject=1, gesture=2, trial=3),
#  Combo(subject=1, gesture=2, trial=4),
#  Combo(subject=1, gesture=2, trial=5),
#  Combo(subject=1, gesture=2, trial=6),
#  Combo(subject=1, gesture=2, trial=7),
#  Combo(subject=1, gesture=2, trial=8),
#  Combo(subject=1, gesture=2, trial=9),
#  Combo(subject=1, gesture=3, trial=0),
#  Combo(subject=1, gesture=3, trial=1),
#  Combo(subject=1, gesture=3, trial=2),
#  Combo(subject=1, gesture=3, trial=3),
#  Combo(subject=1, gesture=3, trial=4),
#  Combo(subject=1, gesture=3, trial=5),
#  Combo(subject=1, gesture=3, trial=6),
#  Combo(subject=1, gesture=3, trial=7),
#  Combo(subject=1, gesture=3, trial=8),
#  Combo(subject=1, gesture=3, trial=9),
#  Combo(subject=1, gesture=4, trial=0),
#  Combo(subject=1, gesture=4, trial=1),
#  Combo(subject=1, gesture=4, trial=2),
#  Combo(subject=1, gesture=4, trial=3),
#  Combo(subject=1, gesture=4, trial=4),
#  Combo(subject=1, gesture=4, trial=5),
#  Combo(subject=1, gesture=4, trial=6),
#  Combo(subject=1, gesture=4, trial=7),
#  Combo(subject=1, gesture=4, trial=8),
#  Combo(subject=1, gesture=4, trial=9),
#  Combo(subject=1, gesture=5, trial=0),
#  Combo(subject=1, gesture=5, trial=1),
#  Combo(subject=1, gesture=5, trial=2),
#  Combo(subject=1, gesture=5, trial=3),
#  Combo(subject=1, gesture=5, trial=4),
#  Combo(subject=1, gesture=5, trial=5),
#  Combo(subject=1, gesture=5, trial=6),
#  Combo(subject=1, gesture=5, trial=7),
#  Combo(subject=1, gesture=5, trial=8),
#  Combo(subject=1, gesture=5, trial=9),
#  Combo(subject=1, gesture=6, trial=0),
#  Combo(subject=1, gesture=6, trial=1),
#  Combo(subject=1, gesture=6, trial=2),
#  Combo(subject=1, gesture=6, trial=3),
#  Combo(subject=1, gesture=6, trial=4),
#  Combo(subject=1, gesture=6, trial=5),
#  Combo(subject=1, gesture=6, trial=6),
#  Combo(subject=1, gesture=6, trial=7),
#  Combo(subject=1, gesture=6, trial=8),
#  Combo(subject=1, gesture=6, trial=9),
#  Combo(subject=1, gesture=7, trial=0),
#  Combo(subject=1, gesture=7, trial=1),
#  Combo(subject=1, gesture=7, trial=2),
#  Combo(subject=1, gesture=7, trial=3),
#  Combo(subject=1, gesture=7, trial=4),
#  Combo(subject=1, gesture=7, trial=5),
#  Combo(subject=1, gesture=7, trial=6),
#  Combo(subject=1, gesture=7, trial=7),
#  Combo(subject=1, gesture=7, trial=8),
#  Combo(subject=1, gesture=7, trial=9),
#  Combo(subject=1, gesture=8, trial=0),
#  Combo(subject=1, gesture=8, trial=1),
#  Combo(subject=1, gesture=8, trial=2),
#  Combo(subject=1, gesture=8, trial=3),
#  Combo(subject=1, gesture=8, trial=4),
#  Combo(subject=1, gesture=8, trial=5),
#  Combo(subject=1, gesture=8, trial=6),
#  Combo(subject=1, gesture=8, trial=7),
#  Combo(subject=1, gesture=8, trial=8),
#  Combo(subject=1, gesture=8, trial=9),
#  Combo(subject=1, gesture=9, trial=0),
#  Combo(subject=1, gesture=9, trial=1),
#  Combo(subject=1, gesture=9, trial=2),
#  Combo(subject=1, gesture=9, trial=3),
#  Combo(subject=1, gesture=9, trial=4),
#  Combo(subject=1, gesture=9, trial=5),
#  Combo(subject=1, gesture=9, trial=6),
#  Combo(subject=1, gesture=9, trial=7),
#  Combo(subject=1, gesture=9, trial=8),
#  Combo(subject=1, gesture=9, trial=9),
#  Combo(subject=1, gesture=10, trial=0),
#  Combo(subject=1, gesture=10, trial=1),
#  Combo(subject=1, gesture=10, trial=2),
#  Combo(subject=1, gesture=10, trial=3),
#  Combo(subject=1, gesture=10, trial=4),
#  Combo(subject=1, gesture=10, trial=5),
#  Combo(subject=1, gesture=10, trial=6),
#  Combo(subject=1, gesture=10, trial=7),
#  Combo(subject=1, gesture=10, trial=8),
#  Combo(subject=1, gesture=10, trial=9),
#  Combo(subject=1, gesture=11, trial=0),
#  Combo(subject=1, gesture=11, trial=1),
#  Combo(subject=1, gesture=11, trial=2),
#  Combo(subject=1, gesture=11, trial=3),
#  Combo(subject=1, gesture=11, trial=4),
#  Combo(subject=1, gesture=11, trial=5),
#  Combo(subject=1, gesture=11, trial=6),
#  Combo(subject=1, gesture=11, trial=7),
#  Combo(subject=1, gesture=11, trial=8),
#  Combo(subject=1, gesture=11, trial=9),
#  Combo(subject=1, gesture=12, trial=0),
#  Combo(subject=1, gesture=12, trial=1),
#  Combo(subject=1, gesture=12, trial=2),
#  Combo(subject=1, gesture=12, trial=3),
#  Combo(subject=1, gesture=12, trial=4),
#  Combo(subject=1, gesture=12, trial=5),
#  Combo(subject=1, gesture=12, trial=6),
#  Combo(subject=1, gesture=12, trial=7),
#  Combo(subject=1, gesture=12, trial=8),
#  Combo(subject=1, gesture=12, trial=9),
#  Combo(subject=1, gesture=13, trial=0),
#  Combo(subject=1, gesture=13, trial=1),
#  Combo(subject=1, gesture=13, trial=2),
#  Combo(subject=1, gesture=13, trial=3),
#  Combo(subject=1, gesture=13, trial=4),
#  Combo(subject=1, gesture=13, trial=5),
#  Combo(subject=1, gesture=13, trial=6),
#  Combo(subject=1, gesture=13, trial=7),
#  Combo(subject=1, gesture=13, trial=8),
#  Combo(subject=1, gesture=13, trial=9),
#  Combo(subject=1, gesture=14, trial=0),
#  Combo(subject=1, gesture=14, trial=1),
#  Combo(subject=1, gesture=14, trial=2),
#  Combo(subject=1, gesture=14, trial=3),
#  Combo(subject=1, gesture=14, trial=4),
#  Combo(subject=1, gesture=14, trial=5),
#  Combo(subject=1, gesture=14, trial=6),
#  Combo(subject=1, gesture=14, trial=7),
#  Combo(subject=1, gesture=14, trial=8),
#  Combo(subject=1, gesture=14, trial=9),
#  Combo(subject=1, gesture=15, trial=0),
#  Combo(subject=1, gesture=15, trial=1),
#  Combo(subject=1, gesture=15, trial=2),
#  Combo(subject=1, gesture=15, trial=3),
#  Combo(subject=1, gesture=15, trial=4),
#  Combo(subject=1, gesture=15, trial=5),
#  Combo(subject=1, gesture=15, trial=6),
#  Combo(subject=1, gesture=15, trial=7),
#  Combo(subject=1, gesture=15, trial=8),
#  Combo(subject=1, gesture=15, trial=9),
#  Combo(subject=1, gesture=16, trial=0),
#  Combo(subject=1, gesture=16, trial=1),
#  Combo(subject=1, gesture=16, trial=2),
#  Combo(subject=1, gesture=16, trial=3),
#  Combo(subject=1, gesture=16, trial=4),
#  Combo(subject=1, gesture=16, trial=5),
#  Combo(subject=1, gesture=16, trial=6),
#  Combo(subject=1, gesture=16, trial=7),
#  Combo(subject=1, gesture=16, trial=8),
#  Combo(subject=1, gesture=16, trial=9),
#  Combo(subject=1, gesture=17, trial=0),
#  Combo(subject=1, gesture=17, trial=1),
#  Combo(subject=1, gesture=17, trial=2),
#  Combo(subject=1, gesture=17, trial=3),
#  Combo(subject=1, gesture=17, trial=4),
#  Combo(subject=1, gesture=17, trial=5),
#  Combo(subject=1, gesture=17, trial=6),
#  Combo(subject=1, gesture=17, trial=7),
#  Combo(subject=1, gesture=17, trial=8),
#  Combo(subject=1, gesture=17, trial=9),
#  Combo(subject=1, gesture=18, trial=0),
#  Combo(subject=1, gesture=18, trial=1),
#  Combo(subject=1, gesture=18, trial=2),
#  Combo(subject=1, gesture=18, trial=3),
#  Combo(subject=1, gesture=18, trial=4),
#  Combo(subject=1, gesture=18, trial=5),
#  Combo(subject=1, gesture=18, trial=6),
#  Combo(subject=1, gesture=18, trial=7),
#  Combo(subject=1, gesture=18, trial=8),
#  Combo(subject=1, gesture=18, trial=9),
#  Combo(subject=1, gesture=19, trial=0),
#  Combo(subject=1, gesture=19, trial=1),
#  Combo(subject=1, gesture=19, trial=2),
#  Combo(subject=1, gesture=19, trial=3),
#  Combo(subject=1, gesture=19, trial=4),
#  Combo(subject=1, gesture=19, trial=5),
#  Combo(subject=1, gesture=19, trial=6),
#  Combo(subject=1, gesture=19, trial=7),
#  Combo(subject=1, gesture=19, trial=8),
#  Combo(subject=1, gesture=19, trial=9),
#  Combo(subject=1, gesture=20, trial=0),
#  Combo(subject=1, gesture=20, trial=1),
#  Combo(subject=1, gesture=20, trial=2),
#  Combo(subject=1, gesture=20, trial=3),
#  Combo(subject=1, gesture=20, trial=4),
#  Combo(subject=1, gesture=20, trial=5),
#  Combo(subject=1, gesture=20, trial=6),
#  Combo(subject=1, gesture=20, trial=7),
#  Combo(subject=1, gesture=20, trial=8),
#  Combo(subject=1, gesture=20, trial=9),
#  Combo(subject=1, gesture=21, trial=0),
#  Combo(subject=1, gesture=21, trial=1),
#  Combo(subject=1, gesture=21, trial=2),
#  Combo(subject=1, gesture=21, trial=3),
#  Combo(subject=1, gesture=21, trial=4),
#  Combo(subject=1, gesture=21, trial=5),
#  Combo(subject=1, gesture=21, trial=6),
#  Combo(subject=1, gesture=21, trial=7),
#  Combo(subject=1, gesture=21, trial=8),
#  Combo(subject=1, gesture=21, trial=9),
#  Combo(subject=1, gesture=22, trial=0),
#  Combo(subject=1, gesture=22, trial=1),
#  Combo(subject=1, gesture=22, trial=2),
#  Combo(subject=1, gesture=22, trial=3),
#  Combo(subject=1, gesture=22, trial=4),
#  Combo(subject=1, gesture=22, trial=5),
#  Combo(subject=1, gesture=22, trial=6),
#  Combo(subject=1, gesture=22, trial=7),
#  Combo(subject=1, gesture=22, trial=8),
#  Combo(subject=1, gesture=22, trial=9),
#  Combo(subject=1, gesture=23, trial=0),
#  Combo(subject=1, gesture=23, trial=1),
#  Combo(subject=1, gesture=23, trial=2),
#  Combo(subject=1, gesture=23, trial=3),
#  Combo(subject=1, gesture=23, trial=4),
#  Combo(subject=1, gesture=23, trial=5),
#  Combo(subject=1, gesture=23, trial=6),
#  Combo(subject=1, gesture=23, trial=7),
#  Combo(subject=1, gesture=23, trial=8),
#  Combo(subject=1, gesture=23, trial=9),
#  Combo(subject=1, gesture=24, trial=0),
#  Combo(subject=1, gesture=24, trial=1),
#  Combo(subject=1, gesture=24, trial=2),
#  Combo(subject=1, gesture=24, trial=3),
#  Combo(subject=1, gesture=24, trial=4),
#  Combo(subject=1, gesture=24, trial=5),
#  Combo(subject=1, gesture=24, trial=6),
#  Combo(subject=1, gesture=24, trial=7),
#  Combo(subject=1, gesture=24, trial=8),
#  Combo(subject=1, gesture=24, trial=9),
#  Combo(subject=1, gesture=25, trial=0),
#  Combo(subject=1, gesture=25, trial=1),
#  Combo(subject=1, gesture=25, trial=2),
#  Combo(subject=1, gesture=25, trial=3),
#  Combo(subject=1, gesture=25, trial=4),
#  Combo(subject=1, gesture=25, trial=5),
#  Combo(subject=1, gesture=25, trial=6),
#  Combo(subject=1, gesture=25, trial=7),
#  Combo(subject=1, gesture=25, trial=8),
#  Combo(subject=1, gesture=25, trial=9),
#  Combo(subject=1, gesture=26, trial=0),
#  Combo(subject=1, gesture=26, trial=1),
#  Combo(subject=1, gesture=26, trial=2),
#  Combo(subject=1, gesture=26, trial=3),
#  Combo(subject=1, gesture=26, trial=4),
#  Combo(subject=1, gesture=26, trial=5),
#  Combo(subject=1, gesture=26, trial=6),
#  Combo(subject=1, gesture=26, trial=7),
#  Combo(subject=1, gesture=26, trial=8),
#  Combo(subject=1, gesture=26, trial=9),
#  Combo(subject=1, gesture=27, trial=0),
#  Combo(subject=1, gesture=27, trial=1),
#  Combo(subject=1, gesture=27, trial=2),
#  Combo(subject=1, gesture=27, trial=3),
#  Combo(subject=1, gesture=27, trial=4),
#  Combo(subject=1, gesture=27, trial=5),
#  Combo(subject=1, gesture=27, trial=6),
#  Combo(subject=1, gesture=27, trial=7),
#  Combo(subject=1, gesture=27, trial=8),
#  Combo(subject=1, gesture=27, trial=9),
#  Combo(subject=1, gesture=28, trial=0),
#  Combo(subject=1, gesture=28, trial=1),
#  Combo(subject=1, gesture=28, trial=2),
#  Combo(subject=1, gesture=28, trial=3),
#  Combo(subject=1, gesture=28, trial=4),
#  Combo(subject=1, gesture=28, trial=5),
#  Combo(subject=1, gesture=28, trial=6),
#  Combo(subject=1, gesture=28, trial=7),
#  Combo(subject=1, gesture=28, trial=8),
#  Combo(subject=1, gesture=28, trial=9),
#  Combo(subject=1, gesture=29, trial=0),
#  Combo(subject=1, gesture=29, trial=1),
#  Combo(subject=1, gesture=29, trial=2),
#  Combo(subject=1, gesture=29, trial=3),
#  Combo(subject=1, gesture=29, trial=4),
#  Combo(subject=1, gesture=29, trial=5),
#  Combo(subject=1, gesture=29, trial=6),
#  Combo(subject=1, gesture=29, trial=7),
#  Combo(subject=1, gesture=29, trial=8),
#  Combo(subject=1, gesture=29, trial=9),
#  Combo(subject=1, gesture=30, trial=0),
#  Combo(subject=1, gesture=30, trial=1),
#  Combo(subject=1, gesture=30, trial=2),
#  Combo(subject=1, gesture=30, trial=3),
#  Combo(subject=1, gesture=30, trial=4),
#  Combo(subject=1, gesture=30, trial=5),
#  Combo(subject=1, gesture=30, trial=6),
#  Combo(subject=1, gesture=30, trial=7),
#  Combo(subject=1, gesture=30, trial=8),
#  Combo(subject=1, gesture=30, trial=9),
#  Combo(subject=1, gesture=31, trial=0),
#  Combo(subject=1, gesture=31, trial=1),
#  Combo(subject=1, gesture=31, trial=2),
#  Combo(subject=1, gesture=31, trial=3),
#  Combo(subject=1, gesture=31, trial=4),
#  Combo(subject=1, gesture=31, trial=5),
#  Combo(subject=1, gesture=31, trial=6),
#  Combo(subject=1, gesture=31, trial=7),
#  Combo(subject=1, gesture=31, trial=8),
#  Combo(subject=1, gesture=31, trial=9),
#  Combo(subject=1, gesture=32, trial=0),
#  Combo(subject=1, gesture=32, trial=1),
#  Combo(subject=1, gesture=32, trial=2),
#  Combo(subject=1, gesture=32, trial=3),
#  Combo(subject=1, gesture=32, trial=4),
#  Combo(subject=1, gesture=32, trial=5),
#  Combo(subject=1, gesture=32, trial=6),
#  Combo(subject=1, gesture=32, trial=7),
#  Combo(subject=1, gesture=32, trial=8),
#  Combo(subject=1, gesture=32, trial=9),
#  Combo(subject=1, gesture=33, trial=0),
#  Combo(subject=1, gesture=33, trial=1),
#  Combo(subject=1, gesture=33, trial=2),
#  Combo(subject=1, gesture=33, trial=3),
#  Combo(subject=1, gesture=33, trial=4),
#  Combo(subject=1, gesture=33, trial=5),
#  Combo(subject=1, gesture=33, trial=6),
#  Combo(subject=1, gesture=33, trial=7),
#  Combo(subject=1, gesture=33, trial=8),
#  Combo(subject=1, gesture=33, trial=9),
#  Combo(subject=1, gesture=34, trial=0),
#  Combo(subject=1, gesture=34, trial=1),
#  Combo(subject=1, gesture=34, trial=2),
#  Combo(subject=1, gesture=34, trial=3),
#  Combo(subject=1, gesture=34, trial=4),
#  Combo(subject=1, gesture=34, trial=5),
#  Combo(subject=1, gesture=34, trial=6),
#  Combo(subject=1, gesture=34, trial=7),
#  Combo(subject=1, gesture=34, trial=8),
#  Combo(subject=1, gesture=34, trial=9),
#  Combo(subject=1, gesture=35, trial=0),
#  Combo(subject=1, gesture=35, trial=1),
#  Combo(subject=1, gesture=35, trial=2),
#  Combo(subject=1, gesture=35, trial=3),
#  Combo(subject=1, gesture=35, trial=4),
#  Combo(subject=1, gesture=35, trial=5),
#  Combo(subject=1, gesture=35, trial=6),
#  Combo(subject=1, gesture=35, trial=7),
#  Combo(subject=1, gesture=35, trial=8),
#  Combo(subject=1, gesture=35, trial=9),
#  Combo(subject=1, gesture=36, trial=0),
#  Combo(subject=1, gesture=36, trial=1),
#  Combo(subject=1, gesture=36, trial=2),
#  Combo(subject=1, gesture=36, trial=3),
#  Combo(subject=1, gesture=36, trial=4),
#  Combo(subject=1, gesture=36, trial=5),
#  Combo(subject=1, gesture=36, trial=6),
#  Combo(subject=1, gesture=36, trial=7),
#  Combo(subject=1, gesture=36, trial=8),
#  Combo(subject=1, gesture=36, trial=9),
#  Combo(subject=1, gesture=37, trial=0),
#  Combo(subject=1, gesture=37, trial=1),
#  Combo(subject=1, gesture=37, trial=2),
#  Combo(subject=1, gesture=37, trial=3),
#  Combo(subject=1, gesture=37, trial=4),
#  Combo(subject=1, gesture=37, trial=5),
#  Combo(subject=1, gesture=37, trial=6),
#  Combo(subject=1, gesture=37, trial=7),
#  Combo(subject=1, gesture=37, trial=8),
#  Combo(subject=1, gesture=37, trial=9),
#  Combo(subject=1, gesture=38, trial=0),
#  Combo(subject=1, gesture=38, trial=1),
#  Combo(subject=1, gesture=38, trial=2),
#  Combo(subject=1, gesture=38, trial=3),
#  Combo(subject=1, gesture=38, trial=4),
#  Combo(subject=1, gesture=38, trial=5),
#  Combo(subject=1, gesture=38, trial=6),
#  Combo(subject=1, gesture=38, trial=7),
#  Combo(subject=1, gesture=38, trial=8),
#  Combo(subject=1, gesture=38, trial=9),
#  Combo(subject=1, gesture=39, trial=0),
#  Combo(subject=1, gesture=39, trial=1),
#  Combo(subject=1, gesture=39, trial=2),
#  Combo(subject=1, gesture=39, trial=3),
#  Combo(subject=1, gesture=39, trial=4),
#  Combo(subject=1, gesture=39, trial=5),
#  Combo(subject=1, gesture=39, trial=6),
#  Combo(subject=1, gesture=39, trial=7),
#  Combo(subject=1, gesture=39, trial=8),
#  Combo(subject=1, gesture=39, trial=9),
#  Combo(subject=1, gesture=40, trial=0),
#  Combo(subject=1, gesture=40, trial=1),
#  Combo(subject=1, gesture=40, trial=2),
#  Combo(subject=1, gesture=40, trial=3),
#  Combo(subject=1, gesture=40, trial=4),
#  Combo(subject=1, gesture=40, trial=5),
#  Combo(subject=1, gesture=40, trial=6),
#  Combo(subject=1, gesture=40, trial=7),
#  Combo(subject=1, gesture=40, trial=8),
#  Combo(subject=1, gesture=40, trial=9),
#  Combo(subject=1, gesture=41, trial=0),
#  Combo(subject=1, gesture=41, trial=1),
#  Combo(subject=1, gesture=41, trial=2),
#  Combo(subject=1, gesture=41, trial=3),
#  Combo(subject=1, gesture=41, trial=4),
#  Combo(subject=1, gesture=41, trial=5),
#  Combo(subject=1, gesture=41, trial=6),
#  Combo(subject=1, gesture=41, trial=7),
#  Combo(subject=1, gesture=41, trial=8),
#  Combo(subject=1, gesture=41, trial=9),
#  Combo(subject=1, gesture=42, trial=0),
#  Combo(subject=1, gesture=42, trial=1),
#  Combo(subject=1, gesture=42, trial=2),
#  Combo(subject=1, gesture=42, trial=3),
#  Combo(subject=1, gesture=42, trial=4),
#  Combo(subject=1, gesture=42, trial=5),
#  Combo(subject=1, gesture=42, trial=6),
#  Combo(subject=1, gesture=42, trial=7),
#  Combo(subject=1, gesture=42, trial=8),
#  Combo(subject=1, gesture=42, trial=9),
#  Combo(subject=1, gesture=43, trial=0),
#  Combo(subject=1, gesture=43, trial=1),
#  Combo(subject=1, gesture=43, trial=2),
#  Combo(subject=1, gesture=43, trial=3),
#  Combo(subject=1, gesture=43, trial=4),
#  Combo(subject=1, gesture=43, trial=5),
#  Combo(subject=1, gesture=43, trial=6),
#  Combo(subject=1, gesture=43, trial=7),
#  Combo(subject=1, gesture=43, trial=8),
#  Combo(subject=1, gesture=43, trial=9),
#  Combo(subject=1, gesture=44, trial=0),
#  Combo(subject=1, gesture=44, trial=1),
#  Combo(subject=1, gesture=44, trial=2),
#  Combo(subject=1, gesture=44, trial=3),
#  Combo(subject=1, gesture=44, trial=4),
#  Combo(subject=1, gesture=44, trial=5),
#  Combo(subject=1, gesture=44, trial=6),
#  Combo(subject=1, gesture=44, trial=7),
#  Combo(subject=1, gesture=44, trial=8),
#  Combo(subject=1, gesture=44, trial=9),
#  Combo(subject=1, gesture=45, trial=0),
#  Combo(subject=1, gesture=45, trial=1),
#  Combo(subject=1, gesture=45, trial=2),
#  Combo(subject=1, gesture=45, trial=3),
#  Combo(subject=1, gesture=45, trial=4),
#  Combo(subject=1, gesture=45, trial=5),
#  Combo(subject=1, gesture=45, trial=6),
#  Combo(subject=1, gesture=45, trial=7),
#  Combo(subject=1, gesture=45, trial=8),
#  Combo(subject=1, gesture=45, trial=9),
#  Combo(subject=1, gesture=46, trial=0),
#  Combo(subject=1, gesture=46, trial=1),
#  Combo(subject=1, gesture=46, trial=2),
#  Combo(subject=1, gesture=46, trial=3),
#  Combo(subject=1, gesture=46, trial=4),
#  Combo(subject=1, gesture=46, trial=5),
#  Combo(subject=1, gesture=46, trial=6),
#  Combo(subject=1, gesture=46, trial=7),
#  Combo(subject=1, gesture=46, trial=8),
#  Combo(subject=1, gesture=46, trial=9),
#  Combo(subject=1, gesture=47, trial=0),
#  Combo(subject=1, gesture=47, trial=1),
#  Combo(subject=1, gesture=47, trial=2),
#  Combo(subject=1, gesture=47, trial=3),
#  Combo(subject=1, gesture=47, trial=4),
#  Combo(subject=1, gesture=47, trial=5),
#  Combo(subject=1, gesture=47, trial=6),
#  Combo(subject=1, gesture=47, trial=7),
#  Combo(subject=1, gesture=47, trial=8),
#  Combo(subject=1, gesture=47, trial=9),
#  Combo(subject=1, gesture=48, trial=0),
#  Combo(subject=1, gesture=48, trial=1),
#  Combo(subject=1, gesture=48, trial=2),
#  Combo(subject=1, gesture=48, trial=3),
#  Combo(subject=1, gesture=48, trial=4),
#  Combo(subject=1, gesture=48, trial=5),
#  Combo(subject=1, gesture=48, trial=6),
#  Combo(subject=1, gesture=48, trial=7),
#  Combo(subject=1, gesture=48, trial=8),
#  Combo(subject=1, gesture=48, trial=9),
#  ...]

# %%
Parallel(n_jobs=8)(delayed(emg_feature_extraction_parallel_2)(input_path, output_path, combo, feature_list) for combo in combos)
